# %% [markdown]
# <a href="https://colab.research.google.com/github/Basab562/FMML20210129/blob/main/%20Module%208_FMML_Lab%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-09 05:48:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   254MB/s    in 0.3s
#
# 2022-06-09 05:48:59 (254 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3003 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12005  1706.01498v2  Recent advances in stochastic gradient techniq...  stat
# 25889  1512.02665v2  Given a food image, can a fine-grained object ...    cs
# 6442   1702.01824v1  Many dimensionality reduction or manifold lear...  stat
# 9187   1607.01274v1  We consider the problem of modeling temporal t...    cs
# 15248  1612.08333v4  We develop models and extract relevant feature...    cs
# ...             ...                                                ...   ...
# 10623  1604.04939v1  Factor analysis aims to determine latent facto...  stat
# 28572  1707.01202v1  Estimating count and density maps from crowd i...    cs
# 24444   1312.6024v1  Due to the high volume of traffic on modern ro...    cs
# 29715  1710.02820v1  Micro-expressions are rapid and involuntary fa...    cs
# 6285   1610.09075v1  This paper compares methods for imputing missi...  stat
#
#                                                    title  year  \
# 12005         Stochastic Gradient Monomial Gamma Sampler  2017
# 25889  Fine-grained Image Classification by Exploring...  2015
# 6442   Learning similarity preserving representations...  2017
# 9187   Temporal Topic Analysis with Endogenous and Ex...  2016
# 15248  Text Summarization using Deep Learning and Rid...  2016
# ...                                                  ...   ...
# 10623  Multi-view Learning as a Nonparametric Nonline...  2016
# 28572  A Survey of Recent Advances in CNN-based Singl...  2017
# 24444  Occupancy Detection in Vehicles Using Fisher V...  2013
# 29715             Micro-Expression Spotting: A Benchmark  2017
# 6285     Missing Data Imputation for Supervised Learning  2016
#
#                                                 keywords
# 12005  [stochastic, techniques, posterior, distributi...
# 25889  [recognition, restaurant, recognition, applica...
# 6442   [dimensionality, reduction, algorithms, retain...
# 9187   [endogenous, exogenous, processes, documents, ...
# 15248  [automatic, summarization, investigate, perfor...
# ...                                                  ...
# 10623  [determine, summarize, nonlinear, nonparametri...
# 28572  [estimating, applications, surveillance, monit...
# 24444  [transportation, occupancy, occupancy, enforce...
# 29715  [expressions, involuntary, expressions, suppre...
# 6285   [categorical, supervised, researchers, accurat...
#
# [4402 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12005    [stochastic, techniques, posterior, distributi...
# 25889    [recognition, restaurant, recognition, applica...
# 6442     [dimensionality, reduction, algorithms, retain...
# 9187     [endogenous, exogenous, processes, documents, ...
# 15248    [automatic, summarization, investigate, perfor...
#                                ...
# 34408    [development, embedding, inspiration, combinin...
# 38582    [localization, technology, localization, parti...
# 11480    [described, documents, characterized, characte...
# 6196     [ubiquitous, streaming, availability, discarde...
# 11027    [reinforcement, popularity, technique, simulat...
# Name: keywords, Length: 5503, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8816 words.
# Out of those 4600 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="643a0de8-ad43-4aad-80d4-68efabfc62df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("643a0de8-ad43-4aad-80d4-68efabfc62df")) {                    Plotly.newPlot(                        "643a0de8-ad43-4aad-80d4-68efabfc62df",                        [{"x":["segmentation","generating","supervoxels","available","benchmarks","generation","supervoxel","resulting","correspond","procedure","distributed","background","drawbacks","algorithms","adaptable","parameters","traditional","parameter","opaqueness","combination","experimental","architectures","employing","identical","recognition","performance","typically","ensembles","predictive","different","classification","individual","competitive","structure","hierarchical","relatively","transparency","convergence","aggregates","specifically","addresses","application","aggregated","contextual","inferring","knowledge","information","occurrences","extraction","relations","embedding","completion","evaluation","interested","outperforms","alternatives","hypothesis","establish","intractable","representation","properties","revisiting","construct","unexplored","interpretable","classifiers","statistics","particular","discovery","interpret","theoretical","classifier","likelihoods","adversarial","generative","uncertainty","distribution","observation","combining","calibrated","condition","estimator","disagreements","alternative","practical","previously","establishing","dimensional","introduce","predictions","simulated","inadequate","euclidean","consistency","prediction","constraint","satisfying","illustrate","technique","aggregation","regression","estimators","collection","experiments","consensus","associated","agreement","numerical","proportion","modelling","following","defeasible","probabilistic","possibilistic","decreasing","nonmonotonic","principle","certainly","projection","approaches","treatment","persistence","reasoning","extrapolating","possibility","conclusions","evolutionary","suggested","architecture","obstacles","monolithic","evolvability","environment","subsumption","corroborate","evolution","incremental","advantages","presented","discussed","integrated","controller","variability","selection","convolutional","community","challenge","neurodegenerative","difficult","morphological","significantly","reproducibility","techniques","comparable","encourage","resonance","comparing","participant","highlighting","significant","improving","neuroimaging","performing","attracted","disorders","structures","restricted","automated","excellent","overcoming","inverting","parallelizable","covariance","asymptotically","synthetic","advantage","realizations","algorithm","expressivity","bottleneck","computational","competing","inference","embarrassingly","adequately","inversion","functions","processes","approximations","maintaining","importance","exploration","dependent","applications","understand","regulating","predictable","implemented","increases","corrected"],"y":[209,95,3,294,98,135,2,135,25,125,104,72,19,608,4,257,191,117,2,120,389,132,27,17,397,896,97,16,56,764,533,124,118,332,115,68,7,106,6,188,53,238,14,32,23,343,689,13,141,99,113,31,247,19,251,25,64,61,26,354,201,8,91,4,27,108,57,277,52,22,157,142,4,77,102,90,239,51,97,6,48,32,0,100,143,93,15,188,353,83,52,7,42,61,215,90,9,63,238,30,110,19,80,630,15,109,22,76,7,39,76,5,143,9,7,13,45,4,64,436,35,1,130,2,41,16,63,35,228,9,4,3,121,2,6,60,33,86,177,70,49,19,26,162,368,72,170,3,141,21,270,3,329,105,20,23,67,3,6,249,94,4,83,23,5,141,56,97,33,7,4,5,21,14,126,101,1,806,4,11,272,22,224,0,9,7,205,112,38,30,78,55,83,401,70,3,4,105,54,5],"type":"bar"},{"x":["segmentation","generating","supervoxels","available","benchmarks","generation","supervoxel","resulting","correspond"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4600,), (4600, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7593097184377838

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Semantic</span> <span style=''>Driven</span> <span style=''>e</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Government</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>of</span> <span style=''>Uschold</span> <span style=''>and</span> <span style=''>King</span> <span style=''>Ontology</span> <span style=''>Building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Methodology</span> <span style=''>for</span> <span style=''>Semantic</span> <span style=''>Ontology</span> <span style=''>Models</span> <span style='background-color:rgba(0, 255, 0, 0.40606060606060607);'>Development</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Electronic</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>government</span> <span style=''>(e</span> <span style=''>government)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>active</span> <span style=''>areas</span> <span style=''>of</span> <span style=''>ontology</span> <span style='background-color:rgba(0, 255, 0, 0.40606060606060607);'>development</span> <span style=''>during</span> <span style=''>the</span> <span style=''>past</span> <span style=''>six</span> <span style=''>years</span> <span style=''>In</span> <span style=''>e</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>government</span> <span style='background-color:rgba(0, 255, 0, 0.9090909090909092);'>ontologies</span> <span style=''>are</span> <span style=''>being</span> <span style=''>used</span> <span style=''>to</span> <span style=''>describe</span> <span style=''>and</span> <span style=''>specify</span> <span style=''>e</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>government</span> <span style=''>services</span> <span style=''>(e</span> <span style=''>services)</span> <span style=''>because</span> <span style=''>they</span> <span style=''>enable</span> <span style=''>easy</span> <span style='background-color:rgba(0, 255, 0, 0.5217391304347827);'>composition</span> <span style=''>matching</span> <span style=''>mapping</span> <span style=''>and</span> <span style=''>merging</span> <span style=''>of</span> <span style=''>various</span> <span style=''>e</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>government</span> <span style=''>services</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importantly</span> <span style=''>they</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.4722222222222223);'>facilitate</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>integration</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>interoperability</span> <span style=''>of</span> <span style=''>e</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>government</span> <span style=''>services</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style=''>still</span> <span style=''>unclear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>current</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>how</span> <span style=''>an</span> <span style=''>existing</span> <span style=''>ontology</span> <span style=''>building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>semantic</span> <span style=''>ontology</span> <span style=''>models</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Distilling</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Knowledge</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Neural</span> <span style=''>Network</span> <br/><br/><span style=''>A</span> <span style=''>very</span> <span style=''>simple</span> <span style=''>way</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>almost</span> <span style=''>any</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>to</span> <span style=''>train</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>models</span> <span style=''>on</span> <span style=''>the</span> <span style=''>same</span> <span style=''>data</span> <span style=''>and</span> <span style=''>then</span> <span style=''>to</span> <span style=''>average</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>using</span> <span style=''>a</span> <span style=''>whole</span> <span style=''>ensemble</span> <span style=''>of</span> <span style=''>models</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumbersome</span> <span style=''>and</span> <span style=''>may</span> <span style=''>be</span> <span style=''>too</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>allow</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deployment</span> <span style=''>to</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>users</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>models</span> <span style=''>are</span> <span style=''>large</span> <span style=''>neural</span> <span style=''>nets</span> <span style=''>Caruana</span> <span style=''>and</span> <span style=''>his</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collaborators</span> <span style=''>have</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>compress</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>in</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>into</span> <span style=''>a</span> <span style=''>single</span> <span style=''>model</span> <span style=''>which</span> <span style=''>is</span> <span style=''>much</span> <span style=''>easier</span> <span style=''>to</span> <span style=''>deploy</span> <span style=''>and</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>further</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>We</span> <span style=''>achieve</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprising</span> <span style=''>resu ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Mixtures</span> <span style=''>of</span> <span style=''>DAG</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>mixtures</span> <span style=''>in</span> <span style=''>which</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>is</span> <span style=''>a</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>(mixtures</span> <span style=''>of</span> <span style=''>DAGs</span> <span style=''>or</span> <span style=''>MDAGs)</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>simple</span> <span style=''>search</span> <span style=''>and</span> <span style=''>score</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>infeasible</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>problems</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>feasible</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>search</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>interleaved</span> <span style=''>and</span> <span style=''>expected</span> <span style=''>data</span> <span style=''>is</span> <span style=''>treated</span> <span style=''>as</span> <span style=''>real</span> <span style=''>data</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>(1)</span> <span style=''>the</span> <span style=''>Cheeseman</span> <span style=''>Stutz</span> <span style='background-color:rgba(255, 0, 0, 0.6274509803921569);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.5958549222797926);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37999999999999995);'>Expectation</span> <span style='background-color:rgba(255, 0, 0, 0.368421052631579);'>Maximization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>We</span> <span style=''>evaluate</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>among</span> <span style=''>MDAGs</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>examples</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>k</span> <span style=''>NN</span> <span style=''>search</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>index</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>for</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>queries</span> <span style=''>are</span> <span style=''>required</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendation</span> <span style=''>systems</span> <span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>spaces</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>methods</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excessive</span> <span style=''>usage</span> <span style=''>of</span> <span style=''>memory</span> <span style=''>and</span> <span style=''>slow</span> <span style=''>response</span> <span style=''>times</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>where</span> <span style=''>multiple</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>trees</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>voting</span> <span style=''>scheme</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancy</span> <span style=''>in</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>sets</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>exact</span> <span style=''>distance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>using</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>reduced</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>footprint</span> <span style=''>and</span> <span style=''>fast</span> <span style=''>index</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>it</span> <span style=''>enables</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10209145693016661)
# 	architecture (0.08082240340304857)
# 	knowledge (0.12158808933002481)
# 	experimental (0.13789436370081531)
# 	segmentation (0.07408720311946118)
# 	information (0.24423963133640553)
# 	detection (0.12229705778092875)
# 	different (0.2708259482453031)
# 	convolutional (0.130450194966324)
# 	recognition (0.14073023750443106)
#
# Some Statistics words are:
# 	variables (0.13441131884790297)
# 	statistical (0.14401212733703891)
# 	stochastic (0.1349166245578575)
# 	distribution (0.1793835270338555)
# 	theoretical (0.15563415866599292)
# 	algorithm (0.38858009095502777)
# 	estimation (0.17281455280444669)
# 	dimensional (0.18140474987367358)
# 	inference (0.19454269833249116)
# 	regression (0.1910055583628095)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="568e7cbc-e447-404c-abef-6765e353d418" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("568e7cbc-e447-404c-abef-6765e353d418")) {                    Plotly.newPlot(                        "568e7cbc-e447-404c-abef-6765e353d418",                        [{"x":["segmentation","generating","supervoxels","available","benchmarks","generation","supervoxel","resulting","correspond","procedure","distributed","background","drawbacks","algorithms","adaptable","parameters","traditional","parameter","opaqueness","combination","experimental","architectures","employing","identical","recognition","performance","typically","ensembles","predictive","different","classification","individual","competitive","structure","hierarchical","relatively","transparency","convergence","aggregates","specifically","addresses","application","aggregated","contextual","inferring","knowledge","information","occurrences","extraction","relations","embedding","completion","evaluation","interested","outperforms","alternatives","hypothesis","establish","intractable","representation","properties","revisiting","construct","unexplored","interpretable","classifiers","statistics","particular","discovery","interpret","theoretical","classifier","likelihoods","adversarial","generative","uncertainty","distribution","observation","combining","calibrated","condition","estimator","disagreements","alternative","practical","previously","establishing","dimensional","introduce","predictions","simulated","inadequate","euclidean","consistency","prediction","constraint","satisfying","illustrate","technique","aggregation","regression","estimators","collection","experiments","consensus","associated","agreement","numerical","proportion","modelling","following","defeasible","probabilistic","possibilistic","decreasing","nonmonotonic","principle","certainly","projection","approaches","treatment","persistence","reasoning","extrapolating","possibility","conclusions","evolutionary","suggested","architecture","obstacles","monolithic","evolvability","environment","subsumption","corroborate","evolution","incremental","advantages","presented","discussed","integrated","controller","variability","selection","convolutional","community","challenge","neurodegenerative","difficult","morphological","significantly","reproducibility","techniques","comparable","encourage","resonance","comparing","participant","highlighting","significant","improving","neuroimaging","performing","attracted","disorders","structures","restricted","automated","excellent","overcoming","inverting","parallelizable","covariance","asymptotically","synthetic","advantage","realizations","algorithm","expressivity","bottleneck","computational","competing","inference","embarrassingly","adequately","inversion","functions","processes","approximations","maintaining","importance","exploration","dependent","applications","understand","regulating","predictable","implemented","increases","corrected","exploitation","effective","substantially","frameworks","dimension","outperform","direction","demonstrate","iterative","correctly","clustering","integrates","complexity","belonging","sufficient","membership","identified","potentially","innovation","simulations","distinguish","optimization","searching","geometrical","mathematical","respective","quadratically","underlying","framework","subspaces","consecutively","intersections","conditions","orthogonal","novelties","algebraic","qualitative","granularity","important","geometric","composition","correctness","statements","navigation","computing","adjustable","strategies","communicative","annotated","according","dependency","additional","neglected","annotations","particularly","furthermore","stochastic","computation","pa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	disagreements
# 	embarrassingly
# 	covariates
# 	autocorrelation
# 	heteroscedastic
# 	prescribe
# 	recidivism
# 	distilling
# 	semiparametric
# 	emphsparse
# 	percentile
# 	chemometrics
# 	inapplicable
# 	microbial
# 	epidemiology
# 	unweighted
# 	conformalized
# 	sparsistent
# 	medication
# 	misclassify
# Some words which never appear in Statistics papers:
# 	supervoxels
# 	supervoxel
# 	adaptable
# 	opaqueness
# 	defeasible
# 	possibilistic
# 	nonmonotonic
# 	obstacles
# 	monolithic
# 	evolvability
# 	subsumption
# 	participant
# 	consecutively
# 	navigation
# 	communicative
# 	neglected
# 	objectness
# 	qualified
# 	soundtrack
# 	inhibition

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.51493848857645e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.6566757493188011
